# %%
import sys
import pandas as pd
from pathlib import Path

# adiciona a raiz do projeto ao PATH
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# importa os módulos
from src.extract import read_csv
from src.cleaning import clean_netflix

# executa o pipeline
df = read_csv('../data/netflix_titles.csv')
df = clean_netflix(df)

# visualiza o resultado
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water     Not Informed
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans     Not Informed
# 4  TV Show           Kota Factory     Not Informed
#
#                                                 cast        country  \
# 0                                       Not Informed  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                       Not Informed        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating  duration  \
# 0 2021-09-25          2020  PG-13        90
# 1 2021-09-24          2021  TV-MA         2
# 2 2021-09-24          2021  TV-MA         1
# 3 2021-09-24          2021  TV-MA         1
# ...

# %%
### dividindo o dataset em duas partes - Movie e TV Show
movie = (df[df['type']=='Movie'].copy().reset_index(drop=True))
tv_show = (df[df['type']=='TV Show'].copy().reset_index(drop=True))
